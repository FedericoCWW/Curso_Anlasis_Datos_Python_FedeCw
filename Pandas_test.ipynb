# %%
import pandas as pd

# %%
datos = {"nombre": ["Pedro", "Juan", "Pepito"], "edad": [25,19,51]}

# %%
print(datos)
# Out:
# {'nombre': ['Pedro', 'Juan', 'Pepito'], 'edad': [25, 19, 51]}

# %%
dataframe = pd.DataFrame(datos)
dataframe
# Out:
#    nombre  edad
# 0   Pedro    25
# 1    Juan    19
# 2  Pepito    51

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe["nombre"]
# Out:
# 0     Pedro
# 1      Juan
# 2    Pepito
# Name: nombre, dtype: object

# %%
datos2 = {"nombre": ['Ana', 'Luis', 'Carlos'], "edad": [30, 25 , 40]}
df2 = pd.DataFrame(datos)
print(df2)
# Out:
#    nombre  edad
# 0   Pedro    25
# 1    Juan    19
# 2  Pepito    51

# %%
df_empleados = pd.DataFrame(datos)

# %%
edades = df_empleados.edad

# %%
print(edades)
# Out:
# 0    25
# 1    19
# 2    51
# Name: edad, dtype: int64

# %%
type(edades)
# Out:
# pandas.core.series.Series

# %%
shapedf, columnsdf, indexdf = df_empleados.shape, df_empleados.columns, df_empleados.index

# %%
print(shapedf, columnsdf, indexdf)
# Out:
# (3, 2) Index(['nombre', 'edad'], dtype='object') RangeIndex(start=0, stop=3, step=1)

# %%
datos_clima = [
    ["Ciudad", "Temperatura", "Precipitaciones"],
    ["Ciudad A", 22, 0],
    ["Ciudad B", 18, 20],
    ["Ciudad C", 15, 5],
    ["Ciudad D", 25, 0],
    ["Ciudad E", 30, 2],
    ["Ciudad F", 20, 15]
]

# %%
df_clima = pd.DataFrame(datos_clima)

# %%
df_clima
# Out:
#           0            1                2
# 0    Ciudad  Temperatura  Precipitaciones
# 1  Ciudad A           22                0
# 2  Ciudad B           18               20
# 3  Ciudad C           15                5
# 4  Ciudad D           25                0
# 5  Ciudad E           30                2
# 6  Ciudad F           20               15

# %%
df_clima.describe()
# Out:
#              0            1  2
# count        7            7  7
# unique       7            7  6
# top     Ciudad  Temperatura  0
# freq         1            1  2

# %%
df_clima.tail
# Out:
# <bound method NDFrame.tail of           0            1                2
# 0    Ciudad  Temperatura  Precipitaciones
# 1  Ciudad A           22                0
# 2  Ciudad B           18               20
# 3  Ciudad C           15                5
# 4  Ciudad D           25                0
# 5  Ciudad E           30                2
# 6  Ciudad F           20               15>

# %%
df_clima.head
# Out:
# <bound method NDFrame.head of           0            1                2
# 0    Ciudad  Temperatura  Precipitaciones
# 1  Ciudad A           22                0
# 2  Ciudad B           18               20
# 3  Ciudad C           15                5
# 4  Ciudad D           25                0
# 5  Ciudad E           30                2
# 6  Ciudad F           20               15>
