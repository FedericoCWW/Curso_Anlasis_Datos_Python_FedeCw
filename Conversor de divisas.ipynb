# %%
nombre, fecha, saludo = "Fede", "5/1/2026", "Buen dia"

# %%
bienvenido = f"{saludo} {nombre}, hoy es {fecha}"

# %%
print(bienvenido)
# Out:
# Buen dia Fede, hoy es 5/1/2026

# %%
dolares = 400.0
euros_a_recibir = dolares * 0.88

# %%
billetes_10 = euros_a_recibir // 10
billetes_1 = (euros_a_recibir - (billetes_10 * 10)) // 1
monedas = euros_a_recibir % 1

# %%
print(f"Billetes de 10: {billetes_10}; Billetes de 1: {billetes_1}; Monedas: {monedas}")
# Out:
# Billetes de 10: 35.0; Billetes de 1: 2.0; Monedas: 0.0
