# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'A': [1,6,9],
    'B': [2,8,3]
})

# %%
df
# Out:
#    A  B
# 0  1  2
# 1  6  8
# 2  9  3

# %%
# conversion Dataframe a Array de Numpy
arr1 = df.values
arr1
# Out:
# array([[1, 2],
#        [6, 8],
#        [9, 3]], dtype=int64)

# %%
arr2 = df.to_numpy()
arr2
# Out:
# array([[1, 2],
#        [6, 8],
#        [9, 3]], dtype=int64)

# %%
np.sqrt(df)
# Out:
#          A         B
# 0  1.00000  1.414214
# 1  2.44949  2.828427
# 2  3.00000  1.732051

# %%
np.max(df)
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# A    9
# B    8
# dtype: int64

# %%
# conversion Array de Numpy a Dataframe
df2 = pd.DataFrame(arr1, columns=['A', 'B'])

# %%
df2
# Out:
#    A  B
# 0  1  2
# 1  6  8
# 2  9  3

# %%
# ej 1

# %%
mi_dataframe = pd.DataFrame({
    "Frutas": ["Manzana", "Banana" , "Cereza"],
    "Cantidad": [5, 8 , 3]
})

# %%
mi_dataframe
# Out:
#     Frutas  Cantidad
# 0  Manzana         5
# 1   Banana         8
# 2   Cereza         3

# %%
mi_dataframe_np = mi_dataframe.values
mi_dataframe_np
# Out:
# array([['Manzana', 5],
#        ['Banana', 8],
#        ['Cereza', 3]], dtype=object)

# %%
# ej 2

# %%
mi_dataframe_filtrado = mi_dataframe[mi_dataframe['Cantidad'] > 4]
mi_dataframe_filtrado
# Out:
#     Frutas  Cantidad
# 0  Manzana         5
# 1   Banana         8

# %%
mi_dataframe_filtrado_np = mi_dataframe_filtrado.values
mi_dataframe_filtrado_np
# Out:
# array([['Manzana', 5],
#        ['Banana', 8]], dtype=object)

# %%
# ej 3

# %%
mi_array = np.array([[10,20,30],[40,50,60]])
mi_array
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
df_numeros = pd.DataFrame(mi_array)
df_numeros
# Out:
#     0   1   2
# 0  10  20  30
# 1  40  50  60
