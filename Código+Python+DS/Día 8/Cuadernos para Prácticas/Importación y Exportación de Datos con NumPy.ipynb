# %%
import numpy as np

# %%
medallas = np.genfromtxt(r"C:\Users\Usuario\Documents\COSAS PYTHON DATA SCIENCE Y ML UDEMY)\medallas_2.csv", delimiter=',', filling_values=0, skip_header=1, dtype='int')

# %%
medallas
# Out:
# array([[  0,   1,   2,   3,   0],
#        [  0,   2,   2,   4,   0],
#        [ 17,   7,  22,  46,   0],
#        [  1,   1,   5,   7,   0],
#        [  0,   3,   4,   7,   0],
#        [  2,   0,   0,   2,   0],
#        [  0,   1,   0,   1,   0],
#        [  1,   3,   3,   7,   0],
#        [  3,   1,   3,   7,   0],
#        [  1,   0,   0,   1,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   6,   8,  21,   0],
#        [  3,   1,   2,   6,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   6,  11,  24,   0],
#        [  2,   4,   6,  12,   0],
#        [  0,   4,   1,   5,   0],
#        [  3,   3,   2,   8,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   3,   5,  15,   0],
#        [  4,   4,   3,  11,   0],
#        [  3,   4,   4,  11,   0],
#        [  0,   3,   2,   5,   0],
#        [  2,   1,   0,   3,   0],
#        [  1,   1,   4,   6,   0],
#        [ 39,  41,  33, 113,   0],
#        [  1,   0,   1,   2,   0],
# ...

# %%
arr_exp = np.array([[1,2,3], [4,5,6]])

# %%
np.savetxt("arr_exportado.csv", arr_exp, delimiter=',', fmt=)
