# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Usuario\Documents\COSAS PYTHON DATA SCIENCE Y ML UDEMY)\Ventas.csv")
df
# Out:
#          Fecha    Producto  Cantidad  Precio Unitario  Total Venta
# 0    1/17/2023  Electrónic         7              200         1400
# 1     9/1/2023  Electrónic         8              200         1600
# 2    7/29/2023    Juguetes         3               30           90
# 3    10/4/2023   Alimentos         4               10           40
# 4    2/28/2023  Electrónic         6              200         1200
# ..         ...         ...       ...              ...          ...
# 995  4/27/2023   Alimentos         2               10           20
# 996   6/9/2023        Ropa        10               50          500
# 997  8/21/2023   Alimentos         8               10           80
# 998  3/28/2023  Electrónic         6              200         1200
# 999   3/7/2023  Electrónic         4              200          800
#
# [1000 rows x 5 columns]

# %%
plt.hist(df['Producto']);

# %%
nums = np.random.randn(1000)
nums
# Out:
# array([ 1.60767069e+00,  1.47589597e+00, -9.11536254e-01, -1.13950061e+00,
#        -5.45913182e-01, -2.02111111e+00, -9.86951038e-01,  1.56047119e+00,
#        -6.87557594e-01,  5.47895287e-01,  1.47970654e+00,  7.70199911e-01,
#         1.65269736e+00,  1.30042856e-01, -7.63405995e-01, -5.69429787e-01,
#         3.41186614e-01, -6.87478974e-01,  1.77208192e+00,  4.83025125e-01,
#         5.72999704e-02, -1.17976781e-01,  1.04632116e+00, -5.49315613e-02,
#         1.59031687e+00,  9.08109215e-01,  2.15299081e+00, -3.23327352e-01,
#         9.65438638e-01,  1.20937986e+00,  1.89176001e-01, -2.65286063e+00,
#        -1.39218948e-01,  9.46101796e-01,  6.02914141e-01,  1.15024423e+00,
#        -1.12702423e+00, -8.23860607e-01,  1.82446590e-01, -4.59335181e-01,
#        -1.01246310e+00, -1.32074928e+00, -8.92793460e-01,  8.83668561e-01,
#        -5.49551744e-02, -9.16143190e-01,  2.35494078e-01, -1.73217623e+00,
# ...

# %%
plt.hist(nums);

# %%
plt.hist(nums, bins=100, color="orange", edgecolor="black", histtype='barstacked');

# %%
x1 = np.random.randn(1000)
x2 = np.random.randn(500)
x3 = np.random.randn(100)

# %%
plt.hist(x1, histtype='stepfilled', color="red", bins=40, alpha=0.5);
plt.hist(x2, histtype='stepfilled', color="blue", bins=40, alpha=0.5);
plt.hist(x3, histtype='stepfilled', color="green", bins=40, alpha=0.5);
