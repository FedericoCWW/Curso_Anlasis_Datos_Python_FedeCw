# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, axs = plt.subplots(ncols=2, nrows=1)
ax1 = axs[0]
ax2 = axs[1];
ax1.plot([1,2,3,4],[5,8,12,9])
ax2.scatter([1,2,3,4],[5,8,12,9])

ax1.set_title("Grafico de linea");
ax2.set_title("Grafico de scatter");
