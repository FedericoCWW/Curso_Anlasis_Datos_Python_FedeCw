# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x = np.linspace(0,10, 30)

# %%
y = np.sin(x)

# %%
plt.plot(x,y,'o');

# %%
alet = np.random.RandomState(0)

# %%
marcadores = ['o', 'x', '+', 'v', 's', 'd']

# %%
for marc in marcadores:
    plt.plot(alet.rand(5),alet.rand(5),marc);

# %%
alet2 = np.random.RandomState(0)
plt.scatter(alet2.randn(100),alet2.randn(100))
plt.grid();
