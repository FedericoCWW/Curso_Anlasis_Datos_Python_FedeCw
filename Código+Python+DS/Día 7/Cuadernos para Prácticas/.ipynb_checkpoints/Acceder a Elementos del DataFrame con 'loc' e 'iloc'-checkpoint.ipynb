# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Col1': [100, 200, 300],
    'Col2': [400, 500, 600],
    'Col3': [700, 800, 900]
}, index=['fila1', 'fila2', 'fila3'])

df
# Out:
#        Col1  Col2  Col3
# fila1   100   400   700
# fila2   200   500   800
# fila3   300   600   900

# %%
df.loc['fila1']
# Out:
# Col1    100
# Col2    400
# Col3    700
# Name: fila1, dtype: int64

# %%
df.loc[['fila1', 'fila3']]
# Out:
#        Col1  Col2  Col3
# fila1   100   400   700
# fila3   300   600   900

# %%
df.loc['fila2':'fila3']
# Out:
#        Col1  Col2  Col3
# fila2   200   500   800
# fila3   300   600   900

# %%
df.loc[[False, True, False]]
# Out:
#        Col1  Col2  Col3
# fila2   200   500   800

# %%
df.loc[df['Col1'] > 150]
# Out:
#        Col1  Col2  Col3
# fila2   200   500   800
# fila3   300   600   900

# %%
df.loc[:,['Col1','Col2']]
# Out:
#        Col1  Col2
# fila1   100   400
# fila2   200   500
# fila3   300   600

# %%
df.iloc[:, [0,1]]
# Out:
#        Col1  Col2
# fila1   100   400
# fila2   200   500
# fila3   300   600

# %%
df.iloc[:, [0]]
# Out:
#        Col1
# fila1   100
# fila2   200
# fila3   300

# %%
# ej 1

# %%
df = pd.DataFrame({
    'Nombre': ['Ana', 'Luis', 'Carmen'],
    'Edad': [25, 30, 22],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia']
}, index=['fila1', 'fila2', 'fila3'])
df
# Out:
#        Nombre  Edad     Ciudad
# fila1     Ana    25     Madrid
# fila2    Luis    30  Barcelona
# fila3  Carmen    22   Valencia

# %%
resultado = df.loc['fila2']
resultado
# Out:
# Nombre         Luis
# Edad             30
# Ciudad    Barcelona
# Name: fila2, dtype: object

# %%
# ej 2

# %%
df2 = pd.DataFrame({
    'Nombre': ['Ana', 'Luis', 'Carmen'],
    'Edad': [25, 30, 22],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia']
}, index=['fila1', 'fila2', 'fila3'])
df2
# Out:
#        Nombre  Edad     Ciudad
# fila1     Ana    25     Madrid
# fila2    Luis    30  Barcelona
# fila3  Carmen    22   Valencia

# %%
resultado2 = df.loc[['fila1', 'fila3']]
resultado2
# Out:
#        Nombre  Edad    Ciudad
# fila1     Ana    25    Madrid
# fila3  Carmen    22  Valencia

# %%
# ej 3

# %%
df3 = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [5, 6, 7, 8],
    'C': [9, 10, 11, 12],
    'D': [13, 14, 15, 16]
})
df3
# Out:
#    A  B   C   D
# 0  1  5   9  13
# 1  2  6  10  14
# 2  3  7  11  15
# 3  4  8  12  16

# %%
resultado3 = df3.iloc[[0,1], [-2,-1]]
resultado3
# Out:
#     C   D
# 0   9  13
# 1  10  14
