# %%
#ej 1
import pandas as pd

# %%
libros = {
    'Titulo': ["El Quijote", "Cien años de soledad", "La odisea"],
    'Autores': ["Miguel de Cervantes", "Gabriel García Márquez", "Homero"],
    'Años': [1605, 1967, 800]
}

# %%
libros_df = pd.DataFrame(libros)

# %%
libros_df
# Out:
#                  Titulo                 Autores  Años
# 0            El Quijote     Miguel de Cervantes  1605
# 1  Cien años de soledad  Gabriel García Márquez  1967
# 2             La odisea                  Homero   800

# %%
#ej 2

# %%
# Datos proporcionados
data = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'Sara'],
    'Edad': [25, 30, 22, 27],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Bilbao']
}
data_df = pd.DataFrame(data)

# %%
data_df
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    25     Madrid
# 1    Luis    30  Barcelona
# 2  Carlos    22   Valencia
# 3    Sara    27     Bilbao

# %%
edad_filtr = data_df[data_df['Edad'] >= 25]

# %%
edad_filtr
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana    25     Madrid
# 1   Luis    30  Barcelona
# 3   Sara    27     Bilbao

# %%
# ej 3

# %%
data2 = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'Sara'],
    'Edad': [25, 30, 22, 27],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Bilbao']
}

# %%
df2 = pd.DataFrame(data2)

# %%
df2
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    25     Madrid
# 1    Luis    30  Barcelona
# 2  Carlos    22   Valencia
# 3    Sara    27     Bilbao

# %%
edad_10_años = df2['Edad'] + 10

# %%
df2['Edad en 10 Años'] = edad_10_años

# %%
df2
# Out:
#    Nombre  Edad     Ciudad  Edad en 10 Años
# 0     Ana    25     Madrid               35
# 1    Luis    30  Barcelona               40
# 2  Carlos    22   Valencia               32
# 3    Sara    27     Bilbao               37

# %%
df2['Ciudad'] = df2['Ciudad'].str.upper()

# %%
df2
# Out:
#    Nombre  Edad     Ciudad  Edad en 10 Años
# 0     Ana    25     MADRID               35
# 1    Luis    30  BARCELONA               40
# 2  Carlos    22   VALENCIA               32
# 3    Sara    27     BILBAO               37

# %%
df2['Es mayor a 25'] = df2['Edad'] >= 25

# %% [markdown]
# df2

# %%
df2
# Out:
#    Nombre  Edad     Ciudad  Edad en 10 Años  Es mayor a 25
# 0     Ana    25     MADRID               35           True
# 1    Luis    30  BARCELONA               40           True
# 2  Carlos    22   VALENCIA               32          False
# 3    Sara    27     BILBAO               37           True
